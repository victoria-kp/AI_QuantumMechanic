# %% [markdown]
# # AI-QuantumMechanic Architecture Diagram
#
# This notebook generates architecture diagrams for the LangGraph-based QM solver.

# %%
import sys
from pathlib import Path

# Add project root to path
project_root = Path.cwd().parent.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from AI_QuantumMechanic.agent.graph import build_graph
from IPython.display import Image, display

# Generate the LangGraph node/edge diagram
app = build_graph()
png_data = app.get_graph().draw_mermaid_png()

# Save and display
output_path = Path("agent_graph.png")
output_path.write_bytes(png_data)
print(f"Saved to {output_path}")
display(Image(png_data))
